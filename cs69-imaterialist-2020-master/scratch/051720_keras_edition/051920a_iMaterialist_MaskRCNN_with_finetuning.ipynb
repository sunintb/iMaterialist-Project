# %% [markdown]
# # A First Attempt for CS69.9/169.9 Kaggle Challenge
#
# **Authors & Affiliation**: David C. & Sunint B. Dartmouth College, Hanover NH 03755
#
# **Acknowledgements** We acknowledge in advance for Kagglers' who shared their code publicly, numerous online documentations, blog posts, Q&A (e.g. StackOverflow), and dataset providers.
#
# Conceptual tutorial that helped a lot: [here](https://lilianweng.github.io/lil-log/2017/12/31/object-recognition-for-dummies-part-3.html#r-cnn)
#
# First, install dependencies (needs to run _every time_ running this notebook) and weight file.

# %%
## In Kaggle kernel, these packages at the right version needs to be install EVERY time! (This is a LIMITATION)
# !pip3 uninstall tensorflow --yes
# !pip3 uninstall keras --yes
# !pip3 install tensorflow==1.15.0
# !pip3 install fancyimpute==0.5.4
# !pip3 install keras==2.1.5
# !pip3 install mrcnn

## Weight for fine-tuning (available on GitHub):
# !wget --quiet https://github.com/matterport/Mask_RCNN/releases/download/v2.1/mask_rcnn_balloon.h5
# Out:
# Found existing installation: tensorflow 2.1.0
# Uninstalling tensorflow-2.1.0:
#   Successfully uninstalled tensorflow-2.1.0
# Found existing installation: Keras 2.3.1
# Uninstalling Keras-2.3.1:
#   Successfully uninstalled Keras-2.3.1
# Collecting tensorflow==1.15.0
#   Downloading tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3 MB)
#      |████████████████████████████████| 412.3 MB 20 kB/s s eta 0:00:01
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.0.8)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.18.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.14.0)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (3.11.4)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.28.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (0.34.2)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.11.2)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 49.2 MB/s eta 0:00:01
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (3.2.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (0.9.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 38.0 MB/s eta 0:00:01
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (2.10.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow==1.15.0) (46.1.3.post20200325)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.2.1)
# ERROR: fancyimpute 0.5.4 requires keras>=2.0.0, which is not installed.
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.1.0
#     Uninstalling tensorflow-estimator-2.1.0:
#       Successfully uninstalled tensorflow-estimator-2.1.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.1.1
#     Uninstalling tensorboard-2.1.1:
#       Successfully uninstalled tensorboard-2.1.1
# Successfully installed tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1
# Requirement already satisfied: fancyimpute==0.5.4 in /opt/conda/lib/python3.7/site-packages (0.5.4)
# Requirement already satisfied: knnimpute in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (0.1.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (1.4.1)
# Collecting keras>=2.0.0
#   Downloading Keras-2.3.1-py2.py3-none-any.whl (377 kB)
#      |████████████████████████████████| 377 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.10 in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (1.18.1)
# Requirement already satisfied: scikit-learn>=0.21.2 in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (0.22.2.post1)
# Requirement already satisfied: tensorflow in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (1.15.0)
# Requirement already satisfied: cvxpy>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from fancyimpute==0.5.4) (1.0.31)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from knnimpute->fancyimpute==0.5.4) (1.14.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from keras>=2.0.0->fancyimpute==0.5.4) (1.0.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras>=2.0.0->fancyimpute==0.5.4) (5.3.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from keras>=2.0.0->fancyimpute==0.5.4) (1.1.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.7/site-packages (from keras>=2.0.0->fancyimpute==0.5.4) (2.10.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.21.2->fancyimpute==0.5.4) (0.14.1)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (1.15.0)
# Requirement already satisfied: gast==0.2.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (3.11.4)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (0.8.1)
# Requirement already satisfied: absl-py>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (0.9.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (1.15.1)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (1.28.1)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (0.34.2)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (1.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.7/site-packages (from tensorflow->fancyimpute==0.5.4) (3.2.1)
# Requirement already satisfied: ecos>=2 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.6->fancyimpute==0.5.4) (2.0.7.post1)
# Requirement already satisfied: osqp>=0.4.1 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.6->fancyimpute==0.5.4) (0.6.1)
# Requirement already satisfied: scs>=1.1.3 in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.6->fancyimpute==0.5.4) (2.1.2)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.7/site-packages (from cvxpy>=1.0.6->fancyimpute==0.5.4) (0.70.9)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->fancyimpute==0.5.4) (46.1.3.post20200325)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->fancyimpute==0.5.4) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow->fancyimpute==0.5.4) (1.0.1)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from osqp>=0.4.1->cvxpy>=1.0.6->fancyimpute==0.5.4) (0.18.2)
# Requirement already satisfied: dill>=0.3.1 in /opt/conda/lib/python3.7/site-packages (from multiprocess->cvxpy>=1.0.6->fancyimpute==0.5.4) (0.3.1.1)
# Installing collected packages: keras
# Successfully installed keras-2.3.1
# Collecting keras==2.1.5
#   Downloading Keras-2.1.5-py2.py3-none-any.whl (334 kB)
#      |████████████████████████████████| 334 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.7/site-packages (from keras==2.1.5) (1.18.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from keras==2.1.5) (5.3.1)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.7/site-packages (from keras==2.1.5) (1.4.1)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from keras==2.1.5) (1.14.0)
# Installing collected packages: keras
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.1.5
# Collecting mrcnn
#   Downloading mrcnn-0.2.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 165 kB/s eta 0:00:011
# Building wheels for collected packages: mrcnn
#   Building wheel for mrcnn (setup.py) ... done
#   Created wheel for mrcnn: filename=mrcnn-0.2-py3-none-any.whl size=54931 sha256=2ec3327e5c2e561a4a04450f9260b18c4c480aa28246249b5e7148c137bf77f4
#   Stored in directory: /root/.cache/pip/wheels/1d/94/0d/03ff96abc43d2d6c8299a92cbb4eced2a1eda3ca7911c19427
# Successfully built mrcnn
# Installing collected packages: mrcnn
# Successfully installed mrcnn-0.2

# %%
# !ls
# Out:
# __notebook_source__.ipynb  mask_rcnn_balloon.h5

# %%
## ML/DL modules:
import mrcnn;
from mrcnn.config import Config;
from mrcnn.utils import Dataset;
from mrcnn.model import MaskRCNN;
from mrcnn import visualize;

import cv2;
import keras;
import tensorflow;
import tensorflow as tf;
from tensorflow.python.keras.engine import saving;
from sklearn.model_selection import train_test_split;

## Utility modules:
import numpy as np ;
import pandas as pd;
import copy as cp;
from pathlib import Path;
import json;
import os;
import warnings;

from matplotlib import pyplot as plt;
import matplotlib.image as mpimg;

keras.engine.saving = saving;
warnings.filterwarnings("ignore");
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
## Constants:
BASENAME = "/kaggle/input/imaterialist-fashion-2020-fgvc7/";
DATA_DIR = Path(BASENAME);
ROOT_DIR = Path("/kaggle/working");
FT_PATH = "/kaggle/working/mask_rcnn_balloon.h5";

## Helper functions:
def read_labels(fname):
    """ Reads labels json file as 2 DataFrames """
    with open(fname, "r") as fh:
        label_dict = json.load(fh);
    fh.close();
    
    categories = pd.DataFrame(label_dict["categories"]).sort_values(by="supercategory");
    attributes = pd.DataFrame(label_dict["attributes"]).sort_values(by="supercategory");
    return label_dict, categories, attributes;

def display_single_img(img, dpi=150):
    """ For EDA """
    plt.figure(dpi=dpi);
    plt.imshow(img);
    plt.show();
    
def summarize_columns(data, columns):
    """Creates data summary"""
    res = {};
    for col in columns:
        res[col] = data[col].describe();
    return pd.DataFrame(res);

# %%
## Load training annotation:
annot_train = pd.read_csv(DATA_DIR/'train.csv');
annot_train.head()
# Out:
#                             ImageId  \
# 0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1  00000663ed1ff0c4e0132b9b9ac53f6e
# 2  00000663ed1ff0c4e0132b9b9ac53f6e
# 3  00000663ed1ff0c4e0132b9b9ac53f6e
# 4  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId  \
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
# 2  8521389 10 8526585 30 8531789 42 8537002 46 85...    5214   3676       28
# 3  12903854 2 12909064 7 12914275 10 12919485 15 ...    5214   3676       31
# 4  10837337 5 10842542 14 10847746 24 10852951 33...    5214   3676       32
#
#                      AttributesIds
# 0  115,136,143,154,230,295,316,317
# 1  115,136,142,146,225,295,316,317
# 2                              163
# 3                          160,204
# 4                              219

# %%
DATA_DICT, CATEGORIES, ATTRIBUTES = read_labels(BASENAME+"label_descriptions.json");
USE_PRETRAINED = True; #depends on competition rule
NUM_CLASSES = len(np.unique(CATEGORIES.name));
NUM_ATTRS = len(np.unique(ATTRIBUTES.name));
print("Number of categoires & attributes are: %d & %d, respectively" % (NUM_CLASSES, NUM_ATTRS))
# Out:
# Number of categoires & attributes are: 46 & 294, respectively

# %% [markdown]
# ## Exploratory Data Analysis

# %%
summarize_columns(annot_train, ["Height","Width"])
# Out:
#               Height         Width
# count  333401.000000  333401.00000
# mean     2235.524021    1761.97925
# std      1543.320481    1425.54039
# min       296.000000     151.00000
# 25%      1024.000000     720.00000
# 50%      1600.000000    1200.00000
# 75%      3000.000000    2275.00000
# max      8688.000000   10717.00000

# %%
def get_random_img_ids(df, key="ImageId", num_imgs=4):
    """
    Gets ides for random images
    :reference: Adapted from Shah K. on Kaggle
    """
    image_ids = df[key].unique();
    return image_ids[np.random.choice(range(len(image_ids)), num_imgs)];

def get_random_images(image_ids, seg_annot=None, subdir="train/", basename=BASENAME):
    """
    Shows random images, either segmented or not
    :param image_ids: IDs for images to plot
    :param seg_annot: If provided, segmented images will be plotted. If None (default), original images will be returned
    :reference: Adapted from Shah K. on Kaggle
    """
    sample_size = len(image_ids);
    raw_images, masks, meta = [], [], []; #init.
    
    ## Load images & meta-data (ref.: Kaggle public notebook)
    for image_id in image_ids:
        image = mpimg.imread(basename+subdir+image_id+".jpg")
        raw_images.append(image);
        if seg_annot is not None:
            meta.append({
                "image": image,
                "shape": image.shape,
                "EncodedPixels": seg_annot[seg_annot["ImageId"] == image_id]["EncodedPixels"],
                "ClassId":  seg_annot[seg_annot["ImageId"] == image_id]["ClassId"]
            });
    
    if seg_annot is None: 
        return raw_images;
    
    ## Impose masks (ref.: Kaggle public notebook)
    for image in meta:
        shape = image.get("shape");
        height, width = shape[ : 2];
        mask = np.zeros((height, width)).reshape(-1);
        
        encoded_pixels = list(image.get("EncodedPixels"));
        class_ids = list(image.get("ClassId"));
        
        for segment, (pixel_str,class_id) in enumerate(zip(encoded_pixels,class_ids)):
            splitted_pixels = list(map(int, pixel_str.split()));
            pixel_starts = splitted_pixels[::2];
            run_lengths = splitted_pixels[1::2];
            
            for pixel_start, run_length in zip(pixel_starts, run_lengths):
                pixel_start = int(pixel_start) - 1;
                run_length = int(run_length);
                mask[pixel_start:pixel_start+run_length] = 255 - class_id * 4;
        
        masks.append(mask.reshape((height, width), order="F"));
    
    return masks, meta;

def plot_multipanel(images, isSegmented=False, num_groups=4, num_per_row=2):
    """
    DEBUGG REQUIRED -- num_groups
    Plots multi-panel images, either segmented or not
    :param isSegmented: If True, then the images object must be a tuple of length 2 with mask & metadata
    :reference: Adapted from Shah K. on Kaggle
    """
    if isSegmented:
        masks, meta = images;
        assert(len(masks) == len(meta));
        sample_size = len(masks);
    else:
        sample_size = len(images);
        
    count = 0;
    for index in range(sample_size // num_groups):
        fig, ax = plt.subplots(nrows=num_per_row, ncols=int(num_groups/num_per_row), figsize=(10,10), dpi=100);
        for row in ax:
            for col in row:
                if isSegmented:
                    col.imshow(meta[count]['image']);
                    col.imshow(masks[count], alpha=0.5);
                
                else:
                    col.imshow(images[count]);
                
                col.axis('off');
                count += 1;
        
        plt.show()

# %%
idx_sele = get_random_img_ids(annot_train); #reusable
idx_sele
# Out:
# array(['b6d87ba855d7a03aef2a842b714f0613',
#        '8076126c05c69658bb00f335c3700c85',
#        '11c29aa84e710adf1f6ad0bd045582b2',
#        '7db96be07b0bf0e22e9c89018d1cbf8d'], dtype=object)

# %%
plot_multipanel(get_random_images(idx_sele, None))

# %%
plot_multipanel(get_random_images(idx_sele, annot_train), True)

# %% [markdown]
# ## Configurations for both Training & Testing

# %%
class CustomConfig(Config):
    """
    Configurations for matterport's MaskRCNN
    :reference github.com/matterport/Mask_RCNN/wiki
    :reference www.kaggle.com/kaushal2896/imaterialist-2020-starter-eda-mask-rcnn
    """
    NAME = "Training"; 
    BACKBONE = "resnet50"; #smaller memory requirement than resnet101; comment out to use default
    GPU_COUNT = 1; 
    IMAGES_PER_GPU = 8; #can be even smaller, e.g. 2

    NUM_CLASSES = CATEGORIES.shape[0] + 1; #extra background class
    
    ## Image sizes:
    IMAGE_MIN_DIM = 256;
    IMAGE_MAX_DIM = IMAGE_MIN_DIM;

    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128);
    TRAIN_ROIS_PER_IMAGE = 32; 
    STEPS_PER_EPOCH = 16; #TODO: consider larger at the end, e.g. 128
    VALIDATION_STEPS = 4;

CONFIG = CustomConfig();
CONFIG.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                59
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           Training
# NUM_CLASSES                    47
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                16
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               4
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Training Keras-based _Mask RCNN_
#
# If model is already trained, then there will be no need to run this, but instead directly load from model.
#
# References:
#
# * Most popular notebook in _iMaterialist_
# * [PyImageSearch](https://www.pyimagesearch.com/2019/06/10/keras-mask-r-cnn/)
# * Dr. J. Brownee's [tutorial](https://machinelearningmastery.com/how-to-perform-object-detection-in-photographs-with-mask-r-cnn-in-keras/)

# %%
class CustomDataset(Dataset):
    """ 
    Class for implementing the MaskRCNN, inheriting from mrcnn.Dataset module
    :note: As this procedure *inherits* from mrcnn.Datasets, much of it needs to be strictly followed
    :note: This is for the training data. Be sure to handle the test data the same way
    """
    ## Static variables:
    IMAGE_SIZE = 256;
    
    def __init__(self, df):
        """ Constructor """
        super().__init__(self);
        self.IMAGE_SIZE = CustomDataset.IMAGE_SIZE; #required
        
        for c in DATA_DICT["categories"]:
            self.add_class("dataset", c.get("id"), c.get("name"));
            
        for i, row in df.iterrows():
            self.add_image(
                "dataset", 
                image_id = row.name,   
                path = str(DATA_DIR/'train'/row.name) + '.jpg', 
                labels = row["ClassId"],
                annotations = row["EncodedPixels"], 
                height = row["Height"], 
                width = row["Width"]
            );
    
    def _resize_image(self, image_path):
        """ 
        Required method; should be used as a static method when preprocessing test set
        :example: CustomDataset._resize_image(CustomDataset, <path-to-image>)
        :reference: codeburst.io/python-3-how-to-use-a-instance-non-static-method-as-static-a2cf21bfd5b4
        """
        shape = (self.IMAGE_SIZE, self.IMAGE_SIZE);
        img = cv2.imread(image_path);
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB);
        img = cv2.resize(img, shape, interpolation=cv2.INTER_AREA);
        return img;
    
    def load_image(self, image_id):
        """ Required method """
        annot = self.image_info[image_id];
        return self._resize_image(annot["path"]);
    
    def image_reference(self, image_id):
        """ Required method """
        annot = self.image_info[image_id];
        return annot["path"], [label for label in annot["labels"]];
    
    def load_mask(self, image_id):
        """ Required method """
        annot = self.image_info[image_id];
        shape_r2 = (self.IMAGE_SIZE, self.IMAGE_SIZE);
        shape_r3 = (self.IMAGE_SIZE, self.IMAGE_SIZE, len(annot["annotations"]));
        mask = np.zeros(shape_r3, dtype=np.uint8);
        
        labels = [];
        for m, (annotation,label) in enumerate(zip(annot["annotations"],annot["labels"])):
            sub_mask = np.full(annot['height']*annot['width'], 0, dtype=np.uint8);
            annotation = [int(x) for x in annotation.split(" ")];
            
            for i, start_px in enumerate(annotation[::2]):
                end_px = start_px + annotation[2*i + 1];
                sub_mask[start_px : end_px] = 1;

            sub_mask = sub_mask.reshape((annot["height"],annot["width"]), order='F');
            sub_mask = cv2.resize(sub_mask, shape_r2, interpolation=cv2.INTER_NEAREST);
            
            mask[:, :, m] = sub_mask;
            labels.append(int(label)+1);
        
        return mask, np.array(labels);

# %%
def get_image_df(df, key="ImageId", agg_fun=lambda x:list(x)):
    """ Wrapper to prepare training annotation """
    image_df = df.groupby(key)["EncodedPixels","ClassId"].agg(agg_fun);
    size_df = df.groupby(key)["Height","Width"].mean();
    image_df = image_df.join(size_df, on=key);
    
    print("Total images: %d" % len(image_df))
    image_df.head()
    return image_df;

annot_train.drop("AttributesIds", axis=1, inplace=True);
image_df = get_image_df(annot_train);
# Out:
# Total images: 45623

# %%
## For development, sub-sample the training set
N_SAMP = 1024;
VAL_PROP = 0.20; #use higher in actual analysis

image_df = image_df.iloc[np.random.choice(range(image_df.shape[0]), N_SAMP)];

def preview_mrcnn_data(dataset, num_imgs=2):
    """ Wrapper to visualize a few images """
    dataset = CustomDataset(dataset);
    dataset.prepare();
    
    for i in range(num_imgs):
        image_id = np.random.choice(dataset.image_ids);
        image = dataset.load_image(image_id);
        mask, class_ids = dataset.load_mask(image_id);
        visualize.display_top_masks(image, mask, class_ids, dataset.class_names, limit=4)

preview_mrcnn_data(image_df);

# %%
## Separately create training & validation sets:
imgs_train, imgs_val = train_test_split(image_df, test_size=VAL_PROP);

Xtrain = CustomDataset(imgs_train); 
Xtrain.prepare();
print("Training Data object: %s" % Xtrain) #ensure NOT Nonetype

Xval = CustomDataset(imgs_train);
Xval.prepare();
print("Validation Data object: %s" % Xval)
# Out:
# Training Data object: <__main__.CustomDataset object at 0x7f9cf77ec690>
# Validation Data object: <__main__.CustomDataset object at 0x7f9cf77c5310>

# %%
model = MaskRCNN(mode="training", config=CONFIG, model_dir=ROOT_DIR);

# %%
## Optional Steps:
## 1. Fine-tune with weights
## 2. Data augmentation, e.g. horizontal flip, white noise, random crop...

H5_EXCL = ["mrcnn_class_logits","mrcnn_bbox_fc","mrcnn_bbox","mrcnn_mask"];
model.load_weights(FT_PATH, by_name=True, exclude=H5_EXCL);

# %%
PARAM_GRID = {"learning_rate": 0.01, "epochs": 3};

model.train(
    Xtrain, 
    Xval,
    learning_rate = PARAM_GRID["learning_rate"],
    epochs = PARAM_GRID["epochs"],
    layers = "heads",
    augmentation = None
);
# Out:
# Starting at epoch 0. LR=0.01
#
# Checkpoint Path: /kaggle/working/training20200518T1500/mask_rcnn_training_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/3
# 16/16 [==============================] - 579s 36s/step - loss: 13.4936 - rpn_class_loss: 1.6105 - rpn_bbox_loss: 5.0614 - mrcnn_class_loss: 1.8902 - mrcnn_bbox_loss: 4.1196 - mrcnn_mask_loss: 0.8119 - val_loss: 10.7660 - val_rpn_class_loss: 0.4530 - val_rpn_bbox_loss: 3.6747 - val_mrcnn_class_loss: 0.3762 - val_mrcnn_bbox_loss: 5.5901 - val_mrcnn_mask_loss: 0.6720
# Epoch 2/3
# 16/16 [==============================] - 453s 28s/step - loss: 10.8559 - rpn_class_loss: 0.4730 - rpn_bbox_loss: 4.8937 - mrcnn_class_loss: 0.1600 - mrcnn_bbox_loss: 4.7485 - mrcnn_mask_loss: 0.5808 - val_loss: 9.3001 - val_rpn_class_loss: 0.2974 - val_rpn_bbox_loss: 5.4195 - val_mrcnn_class_loss: 0.2491 - val_mrcnn_bbox_loss: 2.6857 - val_mrcnn_mask_loss: 0.6484
# Epoch 3/3
# 16/16 [==============================] - 456s 29s/step - loss: 8.4287 - rpn_class_loss: 0.3222 - rpn_bbox_loss: 3.8218 - mrcnn_class_loss: 0.3702 - mrcnn_bbox_loss: 3.2197 - mrcnn_mask_loss: 0.6949 - val_loss: 7.1051 - val_rpn_class_loss: 0.2506 - val_rpn_bbox_loss: 2.9807 - val_mrcnn_class_loss: 0.3966 - val_mrcnn_bbox_loss: 2.7936 - val_mrcnn_mask_loss: 0.6836

# %%
## Save model weights for future inference / downstream exploration
## Can be downloaed via Kaggle Data
model.keras_model.save_weights("my_trained_weights.h5");

# %% [markdown]
# ## Making Prediction on Test Images for Submission
#
# Steps:
#
# * Process the test-set images the same way as training images
#     - Image re-size
#     - Other procedures (e.g. contrast)
# * May need to revert back to the trainings set and make modifications
#
# References:
#
# * [AnalyticsVidhya](https://www.analyticsvidhya.com/blog/2019/07/computer-vision-implementing-mask-r-cnn-image-segmentation/)

# %%
class InferenceConfig(CustomConfig):
    """ Overrides some existing configurations """
    NAME = "test";
    GPU_COUNT = 1;
    IMAGES_PER_GPU = 1;

def get_trained_model(weight_path="/kaggle/working/my_trained_weights.h5"):
    """ 
    Wrapper to return trained model 
    :param use_saved_weights: If True, weights will be loaded. Otherwise, it assumes the workspace has an object `model`
    """
    trained_model = MaskRCNN(mode="inference", config=infConfig, model_dir=ROOT_DIR);
    trained_model.load_weights(weight_path, by_name=True);
    return trained_model;
    
## Test-set configurations:
infConfig = InferenceConfig();
infConfig.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                59
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           test
# NUM_CLASSES                    47
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                16
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               4
# WEIGHT_DECAY                   0.0001

# %%
## Run one of the following:
trained_model = get_trained_model();
# trained_model = model;

# %%
sample_sub_df = pd.read_csv(BASENAME+"sample_submission.csv");
sample_sub_df.head()
# Out:
#                             ImageId EncodedPixels  ClassId AttributesIds
# 0  003d41dd20f271d27219fe7ee6de727d           1 1        0       111,137
# 1  0046f98599f05fd7233973e430d6d04d           1 1        0       111,137
# 2  004e9e21cd1aca568a8ffc77a54638ce           1 1        0       111,137
# 3  005b37fce3c0f641d327d95dd832f51b           1 1        0       111,137
# 4  0094940c58c343b742f48ae26eb5e9fa           1 1        0       111,137

# %%
annot_train.head()
# Out:
#                             ImageId  \
# 0  00000663ed1ff0c4e0132b9b9ac53f6e
# 1  00000663ed1ff0c4e0132b9b9ac53f6e
# 2  00000663ed1ff0c4e0132b9b9ac53f6e
# 3  00000663ed1ff0c4e0132b9b9ac53f6e
# 4  00000663ed1ff0c4e0132b9b9ac53f6e
#
#                                        EncodedPixels  Height  Width  ClassId
# 0  6068157 7 6073371 20 6078584 34 6083797 48 608...    5214   3676        6
# 1  6323163 11 6328356 32 6333549 53 6338742 75 63...    5214   3676        0
# 2  8521389 10 8526585 30 8531789 42 8537002 46 85...    5214   3676       28
# 3  12903854 2 12909064 7 12914275 10 12919485 15 ...    5214   3676       31
# 4  10837337 5 10842542 14 10847746 24 10852951 33...    5214   3676       32

# %%
## Initilaize the object to be assembled into DataFrame for CSV export:
img_test_ids = [x[:-4] for x in os.listdir(BASENAME+"test/")]; #drop ".jpg" extension
img_test_ids = pd.DataFrame({"ImageId":img_test_ids});
img_test_ids.head()
# Out:
#                             ImageId
# 0  cb49b883e995b9102d831e4640c0d195
# 1  2a057ce851e8dbb5b64f0ac8fb264bbf
# 2  79a24ad034125a47b08f50a0387b5643
# 3  019ec2bcca4c8aa6381ae3661f5959ef
# 4  a95fbf0046baf4bb406f4f9e27a70454

# %%
def make_single_pred(prefix, class_names, subdir="test/"):
    img_name = BASENAME + subdir + prefix + ".jpg";
    img = CustomDataset._resize_image(CustomDataset, img_name.item()) #use of instance method as sta
    # display_single_img(img)
    r = trained_model.detect([img], verbose=1);
    r = r[0];
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], class_names, r['scores'])

# %%
make_single_pred(img_test_ids.iloc[np.random.choice(range(len(img_test_ids)))].values, CATEGORIES.supercategory)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-34-8d5eb97784ee> in <module>
# ----> 1 make_single_pred(img_test_ids.iloc[np.random.choice(range(len(img_test_ids)))].values, CATEGORIES.supercategory)
#
# <ipython-input-33-65d9ec233793> in make_single_pred(prefix, class_names, subdir)
#       3     img = CustomDataset._resize_image(CustomDataset, img_name.item()) #use of instance method as sta
#       4     # display_single_img(img)
# ----> 5     r = trained_model.detect([img], verbose=1);
#       6     r = r[0];
#       7     visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], class_names, r['scores'])
#
# /opt/conda/lib/python3.7/site-packages/mrcnn/model.py in detect(self, images, verbose)
#    2469         masks: [H, W, N] instance binary masks
#    2470         """
# -> 2471         assert self.mode == "inference", "Create model in inference mode."
#    2472         assert len(
#    2473             images) == self.config.BATCH_SIZE, "len(images) must be equal to BATCH_SIZE"
#
# AssertionError: Create model in inference mode.
